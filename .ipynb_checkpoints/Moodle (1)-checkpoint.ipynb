# %% [markdown]
# # Anomaly Detection in a time series.
#
# ### **Implementation in cpu load from moodle server in LTH**

# %% [markdown]
# 1. Dependencies

# %%
import pandas as pd
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, recall_score, accuracy_score, precision_score
RANDOM_SEED = 2021 
TEST_PCT = 0.3
LABELS = ["Normal","Fraud"]

# %% [markdown]
# 2. Reading the data

# %%
dataset = pd.read_csv("876.csv")
dataset
# Out:
#                             timestamp    unix-epoch       value
# 0       2022-06-01 18:47:03.625346+00  1.654109e+09   78.480000
# 1       2022-06-01 18:49:03.826399+00  1.654109e+09  135.917031
# 2       2022-06-01 18:48:04.301765+00  1.654109e+09   74.639130
# 3       2022-06-01 18:46:04.039116+00  1.654109e+09  157.000000
# 4       2022-06-01 18:50:04.552654+00  1.654109e+09  118.517699
# ...                               ...           ...         ...
# 434877  2023-03-31 14:13:04.101678+00  1.680272e+09  104.783784
# 434878  2023-03-31 14:24:03.918018+00  1.680273e+09   44.647059
# 434879  2023-03-31 14:21:03.492804+00  1.680272e+09  107.304878
# 434880  2023-03-31 14:19:03.269547+00  1.680272e+09   67.820513
# 434881  2023-03-31 14:22:03.652436+00  1.680273e+09   71.783133
#
# [434882 rows x 3 columns]

# %% [markdown]
# ### 3. Preprocessing the data

# %% [markdown]
# ### 3.1 Checking for nulls

# %%
#check for any  nullvalues 
print("Any nulls in the dataset ",dataset.isnull().values.any() )
print('-------')
# Out:
# Any nulls in the dataset  False
# -------

# %% [markdown]
# ### 3.2 Reshaping the data

# %% [markdown]
# First we sort them chronologically

# %%
# Sorting by time
df = dataset.sort_values('unix-epoch')

# %% [markdown]
# Then we group them by minute precision taking the mean if there are more than one tuple of said minute.

# %%
# Convert 'unix-epoch' column to datetime
df['datetime'] = pd.to_datetime(df['unix-epoch'], unit='s')

# Group by minute and calculate mean
df_grouped = df.groupby(pd.Grouper(key='datetime', freq='1Min')).mean().reset_index()


df_grouped['hour'] = df_grouped['datetime'].dt.floor('H')

df_grouped
# Out:
# <ipython-input-5-3c5f832bf72d>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby(pd.Grouper(key='datetime', freq='1Min')).mean().reset_index()
#                   datetime    unix-epoch       value                hour
# 0      2022-06-01 16:21:00  1.654100e+09   73.074380 2022-06-01 16:00:00
# 1      2022-06-01 16:22:00  1.654101e+09   68.822115 2022-06-01 16:00:00
# 2      2022-06-01 16:23:00  1.654101e+09   70.881279 2022-06-01 16:00:00
# 3      2022-06-01 16:24:00  1.654101e+09   88.367742 2022-06-01 16:00:00
# 4      2022-06-01 16:25:00  1.654101e+09   69.131068 2022-06-01 16:00:00
# ...                    ...           ...         ...                 ...
# 436199 2023-03-31 14:20:00  1.680272e+09  107.853403 2023-03-31 14:00:00
# 436200 2023-03-31 14:21:00  1.680272e+09  107.304878 2023-03-31 14:00:00
# 436201 2023-03-31 14:22:00  1.680273e+09   71.783133 2023-03-31 14:00:00
# 436202 2023-03-31 14:23:00  1.680273e+09   76.673267 2023-03-31 14:00:00
# 436203 2023-03-31 14:24:00  1.680273e+09   44.647059 2023-03-31 14:00:00
#
# [436204 rows x 4 columns]

# %% [markdown]
# Then we check which hours have enough tuples to consider them on the model.

# %%
# Create boolean mask to filter out groups with less than 30 tuples
mask = df_grouped.groupby('hour')['value'].transform('count') >= 30

# Filter DataFrame using the mask
df_filtered = df_grouped[mask]

df_filtered
# Out:
#                   datetime    unix-epoch      value                hour
# 0      2022-06-01 16:21:00  1.654100e+09  73.074380 2022-06-01 16:00:00
# 1      2022-06-01 16:22:00  1.654101e+09  68.822115 2022-06-01 16:00:00
# 2      2022-06-01 16:23:00  1.654101e+09  70.881279 2022-06-01 16:00:00
# 3      2022-06-01 16:24:00  1.654101e+09  88.367742 2022-06-01 16:00:00
# 4      2022-06-01 16:25:00  1.654101e+09  69.131068 2022-06-01 16:00:00
# ...                    ...           ...        ...                 ...
# 436174 2023-03-31 13:55:00  1.680271e+09  48.444444 2023-03-31 13:00:00
# 436175 2023-03-31 13:56:00  1.680271e+09  58.716535 2023-03-31 13:00:00
# 436176 2023-03-31 13:57:00  1.680271e+09  84.803571 2023-03-31 13:00:00
# 436177 2023-03-31 13:58:00  1.680271e+09  40.194805 2023-03-31 13:00:00
# 436178 2023-03-31 13:59:00  1.680271e+09  46.680851 2023-03-31 13:00:00
#
# [434859 rows x 4 columns]

# %% [markdown]
# We now interpolate

# %%
# Perform interpolation to fill missing values
df_filtered['value'] = df_filtered['value'].interpolate()

df_filtered['day'] = df_filtered['datetime'].dt.floor('D')

df_filtered
# Out:
# <ipython-input-7-e0d2764a5a16>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['value'] = df_filtered['value'].interpolate()
# <ipython-input-7-e0d2764a5a16>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['day'] = df_filtered['datetime'].dt.floor('D')
#                   datetime    unix-epoch      value                hour  \
# 0      2022-06-01 16:21:00  1.654100e+09  73.074380 2022-06-01 16:00:00
# 1      2022-06-01 16:22:00  1.654101e+09  68.822115 2022-06-01 16:00:00
# 2      2022-06-01 16:23:00  1.654101e+09  70.881279 2022-06-01 16:00:00
# 3      2022-06-01 16:24:00  1.654101e+09  88.367742 2022-06-01 16:00:00
# 4      2022-06-01 16:25:00  1.654101e+09  69.131068 2022-06-01 16:00:00
# ...                    ...           ...        ...                 ...
# 436174 2023-03-31 13:55:00  1.680271e+09  48.444444 2023-03-31 13:00:00
# 436175 2023-03-31 13:56:00  1.680271e+09  58.716535 2023-03-31 13:00:00
# 436176 2023-03-31 13:57:00  1.680271e+09  84.803571 2023-03-31 13:00:00
# 436177 2023-03-31 13:58:00  1.680271e+09  40.194805 2023-03-31 13:00:00
# 436178 2023-03-31 13:59:00  1.680271e+09  46.680851 2023-03-31 13:00:00
#
#               day
# 0      2022-06-01
# 1      2022-06-01
# 2      2022-06-01
# 3      2022-06-01
# 4      2022-06-01
# ...           ...
# 436174 2023-03-31
# 436175 2023-03-31
# 436176 2023-03-31
# 436177 2023-03-31
# 436178 2023-03-31
#
# [434859 rows x 5 columns]

# %% [markdown]
# We check to see how many days have hours missing

# %%
hour_df = df_filtered.groupby("hour").count()
hour_df = hour_df.reset_index()
hour_df = hour_df.sort_values('hour')



hour_df['day'] = hour_df['hour'].dt.floor('D')
day_df = hour_df.groupby('day').count()
day_df = day_df.reset_index()
day_df = day_df.sort_values('value')
day_df
# Out:
#            day  hour  datetime  unix-epoch  value
# 0   2022-06-01     8         8           8      8
# 303 2023-03-31    12        12          12     12
# 280 2023-03-08    17        17          17     17
# 281 2023-03-09    18        18          18     18
# 282 2023-03-10    18        18          18     18
# ..         ...   ...       ...         ...    ...
# 100 2022-09-09    24        24          24     24
# 99  2022-09-08    24        24          24     24
# 98  2022-09-07    24        24          24     24
# 96  2022-09-05    24        24          24     24
# 151 2022-10-30    24        24          24     24
#
# [304 rows x 5 columns]

# %%
day_df[:15]
# Out:
#            day  hour  datetime  unix-epoch  value
# 0   2022-06-01     8         8           8      8
# 303 2023-03-31    12        12          12     12
# 280 2023-03-08    17        17          17     17
# 281 2023-03-09    18        18          18     18
# 282 2023-03-10    18        18          18     18
# 284 2023-03-12    23        23          23     23
# 205 2022-12-23    24        24          24     24
# 204 2022-12-22    24        24          24     24
# 203 2022-12-21    24        24          24     24
# 202 2022-12-20    24        24          24     24
# 201 2022-12-19    24        24          24     24
# 2   2022-06-03    24        24          24     24
# 198 2022-12-16    24        24          24     24
# 197 2022-12-15    24        24          24     24
# 196 2022-12-14    24        24          24     24

# %% [markdown]
# ### Making a moving window dataset.

# %%
from numpy.lib.stride_tricks import sliding_window_view

data = df_filtered['value']

window_size = 30

windows = sliding_window_view(data, window_size)

windows.shape
# Out:
# (434830, 30)

# %%
import datetime

# Create an empty list to store the arrays
arrays = []
initial_dates = []

# Iterate through the DataFrame
for i in range(len(df_filtered) - 30):
    # Check if the indices are 30 numbers away
    if df_filtered.index[i+30] - df_filtered.index[i] == 30:
        # Extract the values for the consecutive tuples
        values = df_filtered['value'].iloc[i:i+30].values
        # Append the values to the list
        arrays.append(values)
        initial_dates.append(df_filtered['datetime'].values[i])

# Convert the list of arrays to a NumPy array
arrays = np.array(arrays)

print(arrays)


  # if df_filtered[i]['datetime'] - df_filtered[i + 30]['datetime'] == datetime.timedelta(minutes=window_size):
  #   correct_windows.append(df_filtered[i:i+30]['value'])
# Out:
# [[73.07438  68.822115 70.881279 ... 87.605128 76.446237 76.673469]
#  [68.822115 70.881279 88.367742 ... 76.446237 76.673469 79.4625  ]
#  [70.881279 88.367742 69.131068 ... 76.673469 79.4625   83.30315 ]
#  ...
#  [52.5      32.78     53.355556 ... 72.9      48.444444 58.716535]
#  [32.78     53.355556 69.148148 ... 48.444444 58.716535 84.803571]
#  [53.355556 69.148148 55.361111 ... 58.716535 84.803571 40.194805]]

# %%
print(arrays.shape)
# Out:
# (434679, 30)

# %% [markdown]
# ## 4. Training the model

# %% [markdown]
# 4.1 We split the data with a 20% rate.

# %%
data = arrays

train_data, test_data, train_indices, test_indices = train_test_split(
    data, np.arange(len(data)), test_size=0.2, random_state=2021
)

# %%
test_indices
# Out:
# array([ 25204, 126537, 201664, ...,  65401, 389686, 263617])

# %%
train_data.shape
# Out:
# (347743, 30)

# %% [markdown]
# We take them to values from 0 to 1

# %%
min_val = tf.reduce_min(train_data)
max_val = tf.reduce_max(train_data)
train_data = (train_data - min_val) / (max_val - min_val)
test_data = (test_data - min_val) / (max_val - min_val)
train_data = tf.cast(train_data, tf.float32)
test_data = tf.cast(test_data, tf.float32)

# %%
train_data
# Out:
# <tf.Tensor: shape=(347743, 30), dtype=float32, numpy=
# array([[4.6699363e-04, 3.5379772e-04, 3.9185266e-04, ..., 7.8548642e-04,
#         1.5372681e-04, 5.0662027e-04],
#        [7.6185196e-04, 3.8883841e-04, 5.6969345e-04, ..., 0.0000000e+00,
#         2.2606885e-04, 0.0000000e+00],
#        [3.3964583e-04, 6.4580329e-04, 4.2703626e-04, ..., 5.5612932e-04,
#         8.1746490e-04, 8.9443469e-04],
#        ...,
#        [5.8325758e-04, 1.8356788e-04, 9.4948911e-05, ..., 1.8496542e-04,
#         0.0000000e+00, 1.1529511e-04],
#        [1.4260422e-03, 8.7585527e-04, 1.2447698e-03, ..., 5.5566162e-04,
#         1.2849752e-03, 9.9018146e-04],
#        [0.0000000e+00, 0.0000000e+00, 3.3910325e-04, ..., 1.8582859e-03,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)>

# %%
nb_epoch = 50
batch_size = 64
input_dim = train_data.shape[1] #num of columns, 30
encoding_dim = 14
hidden_dim_1 = 7
hidden_dim_3 = 4  
learning_rate = 1e-7

# %%
input_layer = tf.keras.layers.Input(shape=(input_dim, ))
#Encoder
encoder = tf.keras.layers.Dense(encoding_dim, activation="relu", activity_regularizer=tf.keras.regularizers.l2(learning_rate))(input_layer)
encoder=tf.keras.layers.Dropout(0.2)(encoder)
encoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
#encoder = tf.keras.layers.Dense(hidden_dim_2, activation='relu')(encoder)
encoder = tf.keras.layers.Dense(hidden_dim_3, activation=tf.nn.leaky_relu)(encoder)
# Decoder
#decoder = tf.keras.layers.Dense(hidden_dim_2, activation='relu')(encoder)
decoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
decoder=tf.keras.layers.Dropout(0.2)(decoder)
decoder = tf.keras.layers.Dense(encoding_dim, activation='relu')(decoder)
decoder = tf.keras.layers.Dense(input_dim, activation='relu')(decoder)
#Autoencoder
autoencoder = tf.keras.Model(inputs=input_layer, outputs=decoder)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30)]              0
#
#  dense (Dense)               (None, 14)                434
#
#  dropout (Dropout)           (None, 14)                0
#
#  dense_1 (Dense)             (None, 7)                 105
#
#  dense_2 (Dense)             (None, 4)                 32
#
#  dense_3 (Dense)             (None, 7)                 35
#
#  dropout_1 (Dropout)         (None, 7)                 0
#
#  dense_4 (Dense)             (None, 14)                112
#
#  dense_5 (Dense)             (None, 30)                450
#
# =================================================================
# Total params: 1,168
# Trainable params: 1,168
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = tf.keras.callbacks.ModelCheckpoint(filepath="autoencoder_fraud.h5",
                               mode='min', monitor='val_loss', verbose=2, save_best_only=True)
# define our early stopping
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.000001,
    patience=10,
    verbose=1, 
    mode='min',
    restore_best_weights=True)

# %%
autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

# %%
from keras.models import load_model

if os.path.exists('/content/autoencoder_fraud.h5'):
  
  auto_encoder = load_model('/content/autoencoder_fraud.h5')
else:

  history = autoencoder.fit(train_data, train_data,
                      epochs=nb_epoch,
                      batch_size=batch_size,
                      shuffle=True,
                      validation_data=(test_data, test_data),
                      verbose=1,
                      callbacks=[cp, early_stop]
                      ).history

# %%
try:
  plt.plot(history['loss'], linewidth=2, label='Train')
  plt.plot(history['val_loss'], linewidth=2, label='Test')
  plt.legend(loc='upper right')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  # plt.ylim(ymin=0.70,ymax=1)
  plt.show()
except NameError as e:
  print("MOdel is trained")
# Out:
# MOdel is trained

# %%
# from keras.models import load_model
# auto_encoder = load_model('/content/autoencoder_fraud.h5')

# %%
test_x_predictions = autoencoder.predict(test_data)
print(test_x_predictions)
mse = np.mean(np.power(test_data - test_x_predictions, 2), axis=1)
test_labels = np.full((mse.shape), False)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': test_labels})
print(f"Mean Squared Error: {mse}")
error_df
# Out:
# 2717/2717 [==============================] - 4s 1ms/step
# [[0.00000000e+00 0.00000000e+00 8.27148779e-06 ... 5.35570189e-06
#   0.00000000e+00 1.48518147e-05]
#  [0.00000000e+00 0.00000000e+00 1.50827645e-05 ... 4.82447940e-05
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 2.87461789e-05 ... 4.94091437e-05
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 1.72188466e-05 ... 2.63581278e-05
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 7.32240096e-06 ... 1.23689770e-05
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 6.23781489e-06 ... 1.23342425e-05
#   0.00000000e+00 0.00000000e+00]]
# Mean Squared Error: [2.1367380e-07 4.7633981e-07 8.9071625e-07 ... 3.4663561e-08 2.5709005e-07
#  1.8611678e-06]
#        Reconstruction_error  True_class
# 0              2.136738e-07       False
# 1              4.763398e-07       False
# 2              8.907163e-07       False
# 3              1.994908e-06       False
# 4              1.648268e-06       False
# ...                     ...         ...
# 86931          3.709729e-07       False
# 86932          5.827400e-07       False
# 86933          3.466356e-08       False
# 86934          2.570901e-07       False
# 86935          1.861168e-06       False
#
# [86936 rows x 2 columns]

# %%
print(test_x_predictions[1])
print(test_data[1])
# Out:
# [0.0000000e+00 0.0000000e+00 1.5082765e-05 0.0000000e+00 9.6349177e-05
#  1.8794124e-04 0.0000000e+00 4.0917530e-05 8.6519467e-05 5.2021969e-05
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0730222e-04 1.8762883e-04
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 1.2947015e-04 8.0193538e-05
#  2.3291900e-08 4.5806566e-05 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  2.7243339e-05 3.8932678e-05 4.8244794e-05 0.0000000e+00 0.0000000e+00]
# tf.Tensor(
# [0.00033013 0.00060089 0.00086714 0.00048637 0.0004157  0.00091808
#  0.00085906 0.00027876 0.0003391  0.00067369 0.0009314  0.00132476
#  0.00038397 0.00014921 0.00077824 0.         0.00044096 0.00082199
#  0.00080028 0.00025957 0.00014921 0.00074772 0.00044931 0.00048379
#  0.00068715 0.0009345  0.00107691 0.00159092 0.00022381 0.00086683], shape=(30,), dtype=float32)

# %%
groups = error_df.groupby('True_class')
threshold = error_df['Reconstruction_error'].quantile(0.999)
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for normal and fraud data")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
error_df['Reconstruction_error'].quantile(0.999)
# Out:
# 0.002131828453857513

# %%
pred_y = [1 if e > threshold else 0 for e in error_df.Reconstruction_error.values]
error_df['pred'] =pred_y

# %%
anomalies_df = error_df[error_df['pred'] == 1]
anomalies_df
# Out:
#        Reconstruction_error  True_class  pred
# 48                 0.004236       False     1
# 201                0.023393       False     1
# 316                0.023121       False     1
# 772                0.033463       False     1
# 1454               0.013563       False     1
# ...                     ...         ...   ...
# 84189              0.032813       False     1
# 84957              0.002376       False     1
# 85005              0.004011       False     1
# 85299              0.038902       False     1
# 85320              0.024009       False     1
#
# [87 rows x 3 columns]

# %%
# Get the indices from anomalies_df
anomaly_indices = anomalies_df.index.values

# Find the intersection between test_indices and anomaly_indices
matching_indices = []
for index in anomaly_indices:
  matching_indices.append(test_indices[index])
matching_indices = np.array(matching_indices)
print(matching_indices.shape)

# Get the values from df_filtered corresponding to matching_indices
matching_values = df_filtered.loc[matching_indices, 'datetime'].values

# Print the matching datetime values
print(matching_values)
# Out:
# (87,)
# ['2023-03-18T18:55:00.000000000' '2022-09-09T03:53:00.000000000'
#  '2022-09-09T03:54:00.000000000' '2022-09-03T09:08:00.000000000'
#  '2022-07-08T05:48:00.000000000' '2022-08-01T10:44:00.000000000'
#  '2022-06-03T18:35:00.000000000' '2023-01-15T18:35:00.000000000'
#  '2022-07-08T05:51:00.000000000' '2022-06-03T18:43:00.000000000'
#  '2023-02-08T22:35:00.000000000' '2022-12-15T17:53:00.000000000'
#  '2022-12-16T21:46:00.000000000' '2022-12-16T20:53:00.000000000'
#  '2022-12-16T20:44:00.000000000' '2023-03-18T18:37:00.000000000'
#  '2023-01-19T03:46:00.000000000' '2023-03-18T18:47:00.000000000'
#  '2022-12-16T21:30:00.000000000' '2023-03-18T18:33:00.000000000'
#  '2022-09-09T04:09:00.000000000' '2022-12-17T19:54:00.000000000'
#  '2022-09-03T09:25:00.000000000' '2023-03-18T18:49:00.000000000'
#  '2023-01-19T03:31:00.000000000' '2022-07-08T05:46:00.000000000'
#  '2022-12-16T20:41:00.000000000' '2022-12-16T20:58:00.000000000'
#  '2023-03-18T18:43:00.000000000' '2023-03-03T19:44:00.000000000'
#  '2022-07-08T05:42:00.000000000' '2023-03-18T18:44:00.000000000'
#  '2022-12-29T22:37:00.000000000' '2023-02-08T22:47:00.000000000'
#  '2023-03-18T18:34:00.000000000' '2022-09-09T04:18:00.000000000'
#  '2023-03-18T18:29:00.000000000' '2022-09-09T04:05:00.000000000'
#  '2022-12-29T23:02:00.000000000' '2022-06-08T08:26:00.000000000'
#  '2022-12-17T20:04:00.000000000' '2022-12-16T21:34:00.000000000'
#  '2022-09-03T09:22:00.000000000' '2022-12-16T20:46:00.000000000'
#  '2022-08-01T10:36:00.000000000' '2022-06-08T08:15:00.000000000'
#  '2022-12-29T22:58:00.000000000' '2023-03-03T19:57:00.000000000'
#  '2022-09-03T09:21:00.000000000' '2023-03-03T19:50:00.000000000'
#  '2022-12-16T21:49:00.000000000' '2022-06-03T18:34:00.000000000'
#  '2022-06-08T08:25:00.000000000' '2023-01-19T03:55:00.000000000'
#  '2022-12-15T17:49:00.000000000' '2023-03-18T18:45:00.000000000'
#  '2023-01-15T18:27:00.000000000' '2022-06-03T18:40:00.000000000'
#  '2022-08-01T10:43:00.000000000' '2022-09-09T04:00:00.000000000'
#  '2023-03-03T19:51:00.000000000' '2022-09-07T19:22:00.000000000'
#  '2022-09-07T19:09:00.000000000' '2022-06-08T08:27:00.000000000'
#  '2022-12-16T21:41:00.000000000' '2022-06-03T18:28:00.000000000'
#  '2022-12-16T21:48:00.000000000' '2023-01-15T18:16:00.000000000'
#  '2022-12-17T20:08:00.000000000' '2023-02-08T22:39:00.000000000'
#  '2022-12-17T20:06:00.000000000' '2023-03-03T19:39:00.000000000'
#  '2023-03-03T20:05:00.000000000' '2023-02-08T22:25:00.000000000'
#  '2022-06-03T18:41:00.000000000' '2022-12-16T20:48:00.000000000'
#  '2022-08-01T10:38:00.000000000' '2023-03-18T18:42:00.000000000'
#  '2022-08-01T10:55:00.000000000' '2022-09-09T04:19:00.000000000'
#  '2022-07-08T06:06:00.000000000' '2022-09-07T19:26:00.000000000'
#  '2022-09-03T09:06:00.000000000' '2022-12-15T17:41:00.000000000'
#  '2023-03-18T18:46:00.000000000' '2022-06-03T18:33:00.000000000'
#  '2022-09-09T03:52:00.000000000']

# %% [markdown]
# # 5. Ploting the anomalies

# %%
df_filtered['day'] = df_filtered['datetime'].dt.floor('D')
df_filtered
# Out:
# <ipython-input-32-44918aa7bdf8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['day'] = df_filtered['datetime'].dt.floor('D')
#                   datetime    unix-epoch      value                hour  \
# 0      2022-06-01 16:21:00  1.654100e+09  73.074380 2022-06-01 16:00:00
# 1      2022-06-01 16:22:00  1.654101e+09  68.822115 2022-06-01 16:00:00
# 2      2022-06-01 16:23:00  1.654101e+09  70.881279 2022-06-01 16:00:00
# 3      2022-06-01 16:24:00  1.654101e+09  88.367742 2022-06-01 16:00:00
# 4      2022-06-01 16:25:00  1.654101e+09  69.131068 2022-06-01 16:00:00
# ...                    ...           ...        ...                 ...
# 436174 2023-03-31 13:55:00  1.680271e+09  48.444444 2023-03-31 13:00:00
# 436175 2023-03-31 13:56:00  1.680271e+09  58.716535 2023-03-31 13:00:00
# 436176 2023-03-31 13:57:00  1.680271e+09  84.803571 2023-03-31 13:00:00
# 436177 2023-03-31 13:58:00  1.680271e+09  40.194805 2023-03-31 13:00:00
# 436178 2023-03-31 13:59:00  1.680271e+09  46.680851 2023-03-31 13:00:00
#
#               day
# 0      2022-06-01
# 1      2022-06-01
# 2      2022-06-01
# 3      2022-06-01
# 4      2022-06-01
# ...           ...
# 436174 2023-03-31
# 436175 2023-03-31
# 436176 2023-03-31
# 436177 2023-03-31
# 436178 2023-03-31
#
# [434859 rows x 5 columns]

# %%
if not os.path.exists("images"):
    os.mkdir("images")

# %%
# !pip install -U kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)

# %%
import plotly.express as px

for i in range(0,20):
  ap = matching_indices[i] #Anomaly Point
  time = matching_values[i]
  day = df_filtered['day'].values[ap]
  fig = px.line(df_filtered[df_filtered['day'] == day], x='datetime', y="value")
  fig.update_yaxes(ticklabelposition="inside top", title='Webserver request time (s)')
  x0 = time
  x1 = time + pd.DateOffset(hours = 0.5)
  fig.add_vrect(x0=str(x0), x1=str(x1), annotation_text="", annotation_position="top left",
              fillcolor="red", opacity=0.25, line_width=0)
  fig.write_image(f"images/fig{i + 1}.pdf")
  # fig.show()
  print(time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-2c99d15c6ef2> in <cell line: 3>()
#      11   fig.add_vrect(x0=str(x0), x1=str(x1), annotation_text="", annotation_position="top left",
#      12               fillcolor="red", opacity=0.25, line_width=0)
# ---> 13   fig.write_image(f"images/fig{i + 1}.pdf")
#      14   # fig.show()
#      15   print(time)
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3819         import plotly.io as pio
#    3820
# -> 3821         return pio.write_image(self, *args, **kwargs)
#    3822
#    3823     # Static helpers
#
# /usr/local/lib/python3.10/dist-packages/plotly/io/_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     265     # -------------
#     266     # Do this first so we don't create a file if image conversion fails
# --> 267     img_data = to_image(
#     268         fig,
#     269         format=format,
#
# /usr/local/lib/python3.10/dist-packages/plotly/io/_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     142     # ---------------
#     143     fig_dict = validate_coerce_fig_to_dict(fig, validate)
# --> 144     img_bytes = scope.transform(
#     145         fig_dict, format=format, width=width, height=height, scale=scale
#     146     )
#
# /usr/local/lib/python3.10/dist-packages/kaleido/scopes/plotly.py in transform(self, figure, format, width, height, scale)
#     159         if code != 0:
#     160             message = response.get("message", None)
# --> 161             raise ValueError(
#     162                 "Transform failed with error code {code}: {message}".format(
#     163                     code=code, message=message
#
# ValueError: Transform failed with error code 525: Maximum call stack size exceeded
